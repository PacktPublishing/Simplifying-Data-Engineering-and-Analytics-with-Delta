# %% [markdown]
# # Introduction to Spark
# * Spark is available both as a standalone installation or packaged with other offerings such as Hadoop
# * Please follow the instructios to install it for your environment
# * These examples are run on the Databricks managed platform - Databricks is the original creator of Spark - no extra installation is necessary
# * Some commands like display() are convenience functions and run on Databricks, you can always substitute it with show()
# ### Pre-requisites
# * https://spark.apache.org/downloads.html
# * https://www.tutorialspoint.com/apache_spark/apache_spark_installation.htm
# * pip install pyspark
# ### Example References
# * https://sparkbyexamples.com/pyspark-tutorial/

# %%
# Spark Context allows your Spark Application to access Spark Cluster & is the entry point of all Spark functionality
spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[90]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2556758628403379#setting/sparkui/0521-192320-w5waoh4f/driver-8858863754797692558">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.0.0.246:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Spark Data types
# * https://spark.apache.org/docs/latest/sql-ref-datatypes.html

# %%
#dbutils is a databricks utility function 
dbutils.fs.rm('/tmp/ch1', True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[91]: True</div>

# %%
columns = ["State","Name", "Age"]
data = [("TX","Jack", 25), ("NV","Jane",66), ("CO","Bill",79),("CA","Tom",53), ("WY","Shawn",45)]

age_df = spark.sparkContext.parallelize(data).toDF(columns)
age_df.printSchema()
display(age_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- State: string (nullable = true)
# -- Name: string (nullable = true)
# -- Age: long (nullable = true)
#
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>TX</td><td>Jack</td><td>25</td></tr><tr><td>NV</td><td>Jane</td><td>66</td></tr><tr><td>CO</td><td>Bill</td><td>79</td></tr><tr><td>CA</td><td>Tom</td><td>53</td></tr><tr><td>WY</td><td>Shawn</td><td>45</td></tr></tbody></table></div>

# %% [markdown]
# ### Persist dataframe

# %%
age_df.write.format('parquet').save('/tmp/ch1/demographic')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Create external table

# %%
# %sql
DROP DATABASE IF EXISTS ch1 CASCADE;

CREATE DATABASE IF NOT EXISTS ch1;

CREATE TABLE IF NOT EXISTS ch1.demographic
USING parquet 
LOCATION '/tmp/ch1/demographic';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Read data from table

# %%
df = spark.read.table('ch1.demographic')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>State</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>WY</td><td>Shawn</td><td>45</td></tr><tr><td>CA</td><td>Tom</td><td>53</td></tr><tr><td>NV</td><td>Jane</td><td>66</td></tr><tr><td>TX</td><td>Jack</td><td>25</td></tr><tr><td>CO</td><td>Bill</td><td>79</td></tr></tbody></table></div>

# %%
# %sql
SELECT count(*) from ch1.demographic
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>5</td></tr></tbody></table></div>

# %% [markdown]
# ### Analyze data

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+----+----------------+
# summary|State|Name|             Age|
# +-------+-----+----+----------------+
#   count|    5|   5|               5|
#    mean| null|null|            53.6|
#  stddev| null|null|20.5621010599598|
#     min|   CA|Bill|              25|
#     max|   WY| Tom|              79|
# +-------+-----+----+----------------+
#
# </div>

# %%
display(df.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>State</th><th>Name</th><th>Age</th></tr></thead><tbody><tr><td>count</td><td>5</td><td>5</td><td>5</td></tr><tr><td>mean</td><td>null</td><td>null</td><td>53.6</td></tr><tr><td>stddev</td><td>null</td><td>null</td><td>20.5621010599598</td></tr><tr><td>min</td><td>CA</td><td>Bill</td><td>25</td></tr><tr><td>25%</td><td>null</td><td>null</td><td>45</td></tr><tr><td>50%</td><td>null</td><td>null</td><td>53</td></tr><tr><td>75%</td><td>null</td><td>null</td><td>66</td></tr><tr><td>max</td><td>WY</td><td>Tom</td><td>79</td></tr></tbody></table></div>

# %% [markdown]
# ### Transformations

# %%
columns = ["FullName", "SSN"]
data = [("Jack", '011-123-2345'), ("Jane",'022-123-2345'), ("Bill",'033-123-2345'),("Tom",'044-123-2345'), ("Shawn",'055-123-2345')]

identity_df = spark.sparkContext.parallelize(data).toDF(columns)
spark.sql("DROP TABLE IF EXISTS ch1.identity")
identity_df.write.format('parquet').saveAsTable('ch1.identity')
identity_df = spark.sql("SELECT * FROM ch1.identity")
display(identity_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FullName</th><th>SSN</th></tr></thead><tbody><tr><td>Shawn</td><td>055-123-2345</td></tr><tr><td>Bill</td><td>033-123-2345</td></tr><tr><td>Jack</td><td>011-123-2345</td></tr><tr><td>Tom</td><td>044-123-2345</td></tr><tr><td>Jane</td><td>022-123-2345</td></tr></tbody></table></div>

# %% [markdown]
# #### Filters

# %%
age_df.select("Name").show()
age_df.filter(age_df.Name.like('J%')).show()

from pyspark.sql.functions import *
age_df.where(col('Name').like('J%')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+
#  Name|
# +-----+
#  Jack|
#  Jane|
#  Bill|
#   Tom|
# Shawn|
# +-----+
#
# +-----+----+---+
# State|Name|Age|
# +-----+----+---+
#    TX|Jack| 25|
#    NV|Jane| 66|
# +-----+----+---+
#
# +-----+----+---+
# State|Name|Age|
# +-----+----+---+
#    TX|Jack| 25|
#    NV|Jane| 66|
# +-----+----+---+
#
# </div>

# %% [markdown]
# #### Add/Drop columns

# %%
new_df = age_df.withColumn('newField1', lit('X')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+---+---------+
# State| Name|Age|newField1|
# +-----+-----+---+---------+
#    TX| Jack| 25|        X|
#    NV| Jane| 66|        X|
#    CO| Bill| 79|        X|
#    CA|  Tom| 53|        X|
#    WY|Shawn| 45|        X|
# +-----+-----+---+---------+
#
# </div>

# %%
from pyspark.sql.functions import when, col
new_df = age_df.withColumn('newField2', when(col('Name') == 'Jane', 'J').otherwise('Other'))
new_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+---+---------+
# State| Name|Age|newField2|
# +-----+-----+---+---------+
#    TX| Jack| 25|    Other|
#    NV| Jane| 66|        J|
#    CO| Bill| 79|    Other|
#    CA|  Tom| 53|    Other|
#    WY|Shawn| 45|    Other|
# +-----+-----+---+---------+
#
# </div>

# %%
new_df.drop('newField2', 'Age').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+
# State| Name|
# +-----+-----+
#    TX| Jack|
#    NV| Jane|
#    CO| Bill|
#    CA|  Tom|
#    WY|Shawn|
# +-----+-----+
#
# </div>

# %% [markdown]
# #### Aggregates

# %%
age_df.select(count("State").alias('NumStates')).show()
age_df.select(countDistinct("Name", "Age")).show()

age_df.select(avg("Age")).show()
age_df.select(stddev("Age"), sum("Age"), max("Age")).show(truncate=False)

age_df.groupBy('State').max('Age').show()
age_df.orderBy("Name", ascending=False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
# NumStates|
# +---------+
#         5|
# +---------+
#
# +-------------------------+
# count(DISTINCT Name, Age)|
# +-------------------------+
#                         5|
# +-------------------------+
#
# +--------+
# avg(Age)|
# +--------+
#     53.6|
# +--------+
#
# +----------------+--------+--------+
# stddev_samp(Age)|sum(Age)|max(Age)|
# +----------------+--------+--------+
# 20.5621010599598|268     |79      |
# +----------------+--------+--------+
#
# +-----+--------+
# State|max(Age)|
# +-----+--------+
#    CO|      79|
#    TX|      25|
#    WY|      45|
#    CA|      53|
#    NV|      66|
# +-----+--------+
#
# +-----+-----+---+
# State| Name|Age|
# +-----+-----+---+
#    CA|  Tom| 53|
#    WY|Shawn| 45|
#    NV| Jane| 66|
#    TX| Jack| 25|
#    CO| Bill| 79|
# +-----+-----+---+
#
# </div>

# %% [markdown]
# #### Joins

# %%
join_df = age_df.join(identity_df, age_df.Name==identity_df.FullName).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+---+--------+------------+
# State| Name|Age|FullName|         SSN|
# +-----+-----+---+--------+------------+
#    TX| Jack| 25|    Jack|011-123-2345|
#    NV| Jane| 66|    Jane|022-123-2345|
#    CO| Bill| 79|    Bill|033-123-2345|
#    CA|  Tom| 53|     Tom|044-123-2345|
#    WY|Shawn| 45|   Shawn|055-123-2345|
# +-----+-----+---+--------+------------+
#
# </div>
