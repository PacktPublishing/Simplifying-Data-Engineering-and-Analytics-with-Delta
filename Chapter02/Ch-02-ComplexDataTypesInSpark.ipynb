# %% [markdown]
# # Chapter-2

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Structured Data
# * Typically csv data that has a given schema and order & is human readable

# %% [markdown]
# ## Providing Schema

# %%
csv_data = [("Jim","","Smith","36636","M",3000),
    ("Mike","Rose","","40288","M", 5000),
    ("Bob","","Williams","42114","M", 6000),
    ("Marie","Anne","Jones","39192","F",7000),
  ]

schema = StructType([ \
    StructField("firstname",StringType(),True), \
    StructField("middlename",StringType(),True), \
    StructField("lastname",StringType(),True), \
    StructField("id", StringType(), True), \
    StructField("gender", StringType(), True), \
    StructField("wages", IntegerType(), True) \
  ])

df = spark.createDataFrame(data=csv_data,schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- firstname: string (nullable = true)
# -- middlename: string (nullable = true)
# -- lastname: string (nullable = true)
# -- id: string (nullable = true)
# -- gender: string (nullable = true)
# -- wages: integer (nullable = true)
#
# +---------+----------+--------+-----+------+-----+
# firstname|middlename|lastname|id   |gender|wages|
# +---------+----------+--------+-----+------+-----+
# Jim      |          |Smith   |36636|M     |3000 |
# Mike     |Rose      |        |40288|M     |5000 |
# Bob      |          |Williams|42114|M     |6000 |
# Marie    |Anne      |Jones   |39192|F     |7000 |
# +---------+----------+--------+-----+------+-----+
#
# </div>

# %% [markdown]
# ## Save
# * overwrite – mode is used to overwrite the existing file.
# * append – To add the data to the existing file
# * ignore – Ignores write operation when the file already exists.
# * error – This is a default option when the file already exists, it returns an error.

# %%
df.write.mode('overwrite').csv('/tmp/ch2/csv_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Infer schema

# %%
df  = spark.read.format("csv") \
      .option("header", False) \
      .option("inferSchema", True) \
      .load("/tmp/ch2/csv_data").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+--------+-----+---+----+
#   _c0| _c1|     _c2|  _c3|_c4| _c5|
# +-----+----+--------+-----+---+----+
# Marie|Anne|   Jones|39192|  F|7000|
#   Bob|null|Williams|42114|  M|6000|
#   Jim|null|   Smith|36636|  M|3000|
#  Mike|Rose|    null|40288|  M|5000|
# +-----+----+--------+-----+---+----+
#
# </div>

# %% [markdown]
# ## Read
# * Specify header, delimmiter, inference

# %%
df_with_schema = spark.read.format("csv") \
      .option("header", False) \
      .schema(schema) \
      .load("/tmp/ch2/csv_data")

df_with_schema.show()
df_with_schema.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+--------+-----+------+-----+
# firstname|middlename|lastname|   id|gender|wages|
# +---------+----------+--------+-----+------+-----+
#     Marie|      Anne|   Jones|39192|     F| 7000|
#       Bob|      null|Williams|42114|     M| 6000|
#       Jim|      null|   Smith|36636|     M| 3000|
#      Mike|      Rose|    null|40288|     M| 5000|
# +---------+----------+--------+-----+------+-----+
#
# root
# -- firstname: string (nullable = true)
# -- middlename: string (nullable = true)
# -- lastname: string (nullable = true)
# -- id: string (nullable = true)
# -- gender: string (nullable = true)
# -- wages: integer (nullable = true)
#
# </div>

# %% [markdown]
# ## Providing Nested Schema

# %%
csv_data = [(("Jim","","Smith"),"36636","M",3000),
    (("Mike","Rose",""),"40288","M", 5000),
    (("Bob","","Williams"),"42114","M", 6000),
    (("Marie","Anne","Jones"),"39192","F",7000),
  ]
schema = StructType([ \
   StructField("name",  StructType([ \
        StructField("firstname",StringType(),True), \
        StructField("middlename",StringType(),True), \
        StructField("lastname",StringType(),True)])), \
    StructField("id", StringType(), True), \
    StructField("gender", StringType(), True), \
    StructField("wages", IntegerType(), True) \
  ])

df = spark.createDataFrame(data=csv_data,schema=schema)
df.printSchema()
df.show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- name: struct (nullable = true)
#     |-- firstname: string (nullable = true)
#     |-- middlename: string (nullable = true)
#     |-- lastname: string (nullable = true)
# -- id: string (nullable = true)
# -- gender: string (nullable = true)
# -- wages: integer (nullable = true)
#
# +--------------------+-----+------+-----+
# name                |id   |gender|wages|
# +--------------------+-----+------+-----+
# {Jim, , Smith}      |36636|M     |3000 |
# {Mike, Rose, }      |40288|M     |5000 |
# {Bob, , Williams}   |42114|M     |6000 |
# {Marie, Anne, Jones}|39192|F     |7000 |
# +--------------------+-----+------+-----+
#
# </div>

# %% [markdown]
# # Semi-Structured Data
# * Typically xml &. json data
# * Unlike structured data, not all columns/fields are present for each record and the order is less important as the data is self-describing

# %%
def jsonToDataFrame(json, schema=None):
  reader = spark.read
  if schema:
    reader.schema(schema)
  return reader.json(sc.parallelize([json]))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## StructType & StructField

# %%
#StructType & StructField
schema = StructType() \
    .add("Person", StructType()
         .add("Name", StringType())
         .add("Age", IntegerType()))
                     
json_str = ''' 
{
  "Person": {
     "Name": "John Smith",
     "Age": 36
  }
}
'''
events = jsonToDataFrame(json_str, schema)
#Individual field access
events.select("Person.Name").show()
#Get all fields 
events.select("Person.*").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
#       Name|
# +----------+
# John Smith|
# +----------+
#
# +----------+---+
#       Name|Age|
# +----------+---+
# John Smith| 36|
# +----------+---+
#
# </div>

# %% [markdown]
# ## Infer Schema

# %%
json_str = ''' 
{
  "Person": {
     "Name": "John Smith",
     "Age": 36
  }
}
'''
#Note schema is not specified
events = jsonToDataFrame(json_str)
#Individual field access
events.select("Person.Name").show()
#Get all fields from a given node
events.select("Person.*").show()
#Get all fields using alias
events.select(struct("*").alias("Citizen")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
#       Name|
# +----------+
# John Smith|
# +----------+
#
# +---+----------+
# Age|      Name|
# +---+----------+
#  36|John Smith|
# +---+----------+
#
# +------------------+
#            Citizen|
# +------------------+
# {{36, John Smith}}|
# +------------------+
#
# </div>

# %% [markdown]
# ## Multi-line

# %%
dbutils.fs.rm('/tmp/test_multilie.json', True)
dbutils.fs.put('/tmp/test_multilie.json',
               '''[{
  "RecordNumber": 2,
  "Zipcode": 704,
  "ZipCodeType": "STANDARD",
  "City": "PASEO COSTA DEL SUR",
  "State": "PR"
},
{
  "RecordNumber": 10,
  "Zipcode": 709,
  "ZipCodeType": "STANDARD",
  "City": "BDA SAN LUIS",
  "State": "PR"
}]''')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 238 bytes.
# Out[24]: True</div>

# %%
events = spark.read.option("multiline", True).json('/tmp/test_multilie.json')
events.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------+-----+-----------+-------+
#                City|RecordNumber|State|ZipCodeType|Zipcode|
# +-------------------+------------+-----+-----------+-------+
# PASEO COSTA DEL SUR|           2|   PR|   STANDARD|    704|
#        BDA SAN LUIS|          10|   PR|   STANDARD|    709|
# +-------------------+------------+-----+-----------+-------+
#
# </div>

# %% [markdown]
# ## Arrays

# %%
#StructType & StructField
schema = StructType() \
    .add("Person", StructType()
         .add("Name", ArrayType(StringType()))
         .add("Age", IntegerType()))

json_str = ''' 
{
  "Person": {
     "Name": ["John","Smith"],
     "Age": 36
  }
}
'''
events = jsonToDataFrame(json_str, schema)
#Individual field access
events.select("Person.Name").show()
#Access Individual elements of the array
events.select((col("Person.Name")).getItem(0)).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
#          Name|
# +-------------+
# [John, Smith]|
# +-------------+
#
# +--------------+
# Person.Name[0]|
# +--------------+
#           John|
# +--------------+
#
# </div>

# %% [markdown]
# ## Maps

# %%
#StructType & StructField
schema = StructType() \
    .add("Person", StructType()
         .add("Name", MapType(StringType(), StringType()))
         .add("Age", IntegerType()))

json_str = ''' 
{
  "Person": {
     "Name": {"John":"Smith"},
     "Age": 36
  }
}
'''
events = jsonToDataFrame(json_str, schema)
#Individual field access
events.select("Person.Name").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+
#            Name|
# +---------------+
# {John -&gt; Smith}|
# +---------------+
#
# </div>

# %% [markdown]
# ## from_json

# %%
events = jsonToDataFrame("""
{
  "Person": "{\\"Address\\":{\\"Unit\\":12,\\"Location\\":{\\"Street\\":\\"New York\\"}}}"
}
""")
 
schema = StructType().add("Address", StructType().add("Unit", IntegerType())
                                                .add("Location", StringType()))
display(events.select(from_json("Person", schema).alias("Citizen")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Citizen</th></tr></thead><tbody><tr><td>List(List(12, {"Street":"New York"}))</td></tr></tbody></table></div>

# %% [markdown]
# ## to_json

# %%
events = jsonToDataFrame("""
{
  "Person": {
     "Name": {"John":"Smith"},
     "Age": 36
  }
}
""")
 
display(events.select(to_json("Person").alias("Citizen")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Citizen</th></tr></thead><tbody><tr><td>{"Age":36,"Name":{"John":"Smith"}}</td></tr></tbody></table></div>

# %% [markdown]
# ## json_tuple

# %%
events = jsonToDataFrame("""
{
  "Person": "{\\"Address\\":{\\"Unit\\":12,\\"Location\\":{\\"Street\\":\\"New York\\"}}}"
}
""")
 
display(events.select(json_tuple("Person", "Address").alias("Address")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Address</th></tr></thead><tbody><tr><td>{"Unit":12,"Location":{"Street":"New York"}}</td></tr></tbody></table></div>

# %% [markdown]
# ## regexp_extract

# %%
events = jsonToDataFrame("""
[{ "Identity": "010-22-2345" }, 
 { "Identity": "017-26-8345" },
 { "Identity": "1-2-3" }]
""")
 
events.select(regexp_extract("Identity", "([0-9]*)-([0-9]*)-([0-9]*)", 1).alias("Identity")).show()
events.select(regexp_extract("Identity", "([0-9]*)-([0-9]*)-([0-9]*)",3).alias("Identity")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------+
# Identity|
# +--------+
#      010|
#      017|
#        1|
# +--------+
#
# +--------+
# Identity|
# +--------+
#     2345|
#     8345|
#        3|
# +--------+
#
# </div>

# %% [markdown]
# ## aggregation

# %%
events = jsonToDataFrame("""
[{ "Name": "John", "Age": 27 }, 
 { "Name": "John", "Age": 52 }]
""")
 
display(events.groupBy("Name").agg(collect_list("Age").alias("Ages")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Name</th><th>Ages</th></tr></thead><tbody><tr><td>John</td><td>List(27, 52)</td></tr></tbody></table></div>

# %% [markdown]
# ## explode

# %%
events = jsonToDataFrame("""
{
 "John" : {
  "Preferences": ['Tennis', 'Cricket']
  }
}
""")
 
display(events.select(explode("John.Preferences").alias("taste")))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>taste</th></tr></thead><tbody><tr><td>Tennis</td></tr><tr><td>Cricket</td></tr></tbody></table></div>
